# %%
# %matplotlib inline
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import skimage.io as skio
import timage_v2 as tim2
import ncempy.io as ncio

# %%
pic1_file = '/Users/cgroschner/Documents/pythonLearn/groschner-python-ay250-homework/final_project/demo_data/select_slid_window/20180227_101729F_plasma15sec_Mh370kx__0013_320_512.png'

# %%
pic1 = skio.imread(pic1_file, as_grey= True)

# %%
tim2.imm(pic1)

# %%
pic1_fft = np.fft.fftshift(np.log2(np.abs(np.sqrt(np.square(np.fft.fft2(pic1))))))

# %%
pic1_fft.dtype
# Out:
# dtype('float64')

# %%
tim2.imm(pic1_fft)

# %%
dm3_1 = ncio.dm.dmReader('/Users/cgroschner/Box Sync/Research/HR-TEM/particleRecognition/20180117/101727H_sampleprep20180116/101727H_plasma15sec_Mh370kx__0008.dm3')

# %%
dm3_1
# Out:
# {'filename': '101727H_plasma_Mh295kx_0006.dm3',
#  'data': array([[1616, 1711, 1818, ..., 1685, 1634, 1596],
#         [1606, 1782, 2123, ..., 1577, 1512, 1582],
#         [1644, 1812, 1951, ..., 1485, 1562, 1622],
#         ...,
#         [1654, 1785, 1702, ..., 1738, 1865, 1916],
#         [1620, 1821, 1757, ..., 1834, 1918, 1848],
#         [1625, 1679, 1665, ..., 1686, 1713, 1836]], dtype=int32),
#  'pixelUnit': ['nm', 'nm'],
#  'pixelSize': [0.041433357, 0.041433357],
#  'pixelOrigin': [0.0, 0.0]}

# %%
dm3_1
# Out:
# {'filename': '101727H_plasma_Mh295kx_0045.dm3',
#  'data': array([[1998, 2083, 2050, ..., 2073, 1836, 1904],
#         [1908, 1965, 2001, ..., 1921, 1852, 1952],
#         [1935, 1940, 1897, ..., 1892, 2041, 2083],
#         ...,
#         [1917, 1962, 2000, ..., 1806, 1750, 1715],
#         [1834, 2055, 1959, ..., 1858, 1821, 1813],
#         [1745, 1998, 1947, ..., 1887, 1812, 1899]], dtype=int32),
#  'pixelUnit': ['nm', 'nm'],
#  'pixelSize': [0.041433357, 0.041433357],
#  'pixelOrigin': [0.0, 0.0]}

# %%
dm3_1
# Out:
# {'filename': '101727H_plasma_Mh370kx_0162.dm3',
#  'data': array([[431, 475, 445, ..., 489, 454, 457],
#         [414, 397, 446, ..., 473, 490, 500],
#         [366, 401, 441, ..., 407, 389, 416],
#         ...,
#         [368, 418, 361, ..., 422, 436, 379],
#         [402, 456, 406, ..., 429, 423, 377],
#         [422, 417, 355, ..., 423, 413, 384]], dtype=int32),
#  'pixelUnit': ['nm', 'nm'],
#  'pixelSize': [0.03297349, 0.03297349],
#  'pixelOrigin': [0.0, 0.0]}

# %%
dm3_1
# Out:
# {'filename': '101727H_plasma15sec_Mh370kx__0008.dm3',
#  'data': array([[448, 392, 362, ..., 363, 390, 368],
#         [397, 405, 315, ..., 383, 362, 382],
#         [368, 354, 329, ..., 353, 365, 340],
#         ...,
#         [380, 422, 362, ..., 406, 409, 339],
#         [381, 434, 417, ..., 359, 385, 366],
#         [399, 413, 406, ..., 373, 358, 325]], dtype=int32),
#  'pixelUnit': ['nm', 'nm'],
#  'pixelSize': [0.03297349, 0.03297349],
#  'pixelOrigin': [0.0, 0.0]}
